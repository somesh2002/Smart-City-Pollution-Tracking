# %%
# !pip3 install geojsoncontour
# Out:
# Collecting geojsoncontour
#   Downloading geojsoncontour-0.4.0-py3-none-any.whl (7.3 kB)
# Requirement already satisfied: matplotlib in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from geojsoncontour) (3.5.0)
# WARNING: Ignoring invalid distribution -ip (c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# Requirement already satisfied: numpy in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from geojsoncontour) (1.21.3)
# Collecting geojson
#   Downloading geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Collecting xarray
#   Downloading xarray-2022.3.0-py3-none-any.whl (870 kB)
#      ------------------------------------- 870.9/870.9 kB 60.8 kB/s eta 0:00:00
# Requirement already satisfied: pillow>=6.2.0 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->geojsoncontour) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->geojsoncontour) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->geojsoncontour) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->geojsoncontour) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->geojsoncontour) (4.28.3)
# Requirement already satisfied: setuptools-scm>=4 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->geojsoncontour) (6.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->geojsoncontour) (21.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->geojsoncontour) (0.11.0)
# Requirement already satisfied: pandas>=1.1 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from xarray->geojsoncontour) (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas>=1.1->xarray->geojsoncontour) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7->matplotlib->geojsoncontour) (1.16.0)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\site-packages (from setuptools-scm>=4->matplotlib->geojsoncontour) (58.1.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from setuptools-scm>=4->matplotlib->geojsoncontour) (1.2.2)
# Installing collected packages: geojson, xarray, geojsoncontour
# Successfully installed geojson-2.5.0 geojsoncontour-0.4.0 xarray-2022.3.0
# WARNING: Ignoring invalid distribution -ip (c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)

# %%
import pandas as pd
import fastparquet
import numpy as np
import seaborn as sns
import matplotlib.pyplot as mp
import os
from fastparquet import ParquetFile
import folium
import shutil
from scipy.interpolate import griddata
from folium import plugins
from folium.plugins import HeatMap
import datetime

# %%
path = "./dataset"
files = [file for file in os.listdir(path) if not file.startswith('.')]
all_months_data = pd.DataFrame()
for file in files:
    current_data = ParquetFile(path+"/"+file).to_pandas()
    all_months_data = pd.concat([all_months_data, current_data])
all_months_data.to_csv("yearlyAnalysis.csv", index=False)

# %%
combined_data = pd.read_csv("yearlyAnalysis.csv")
combined_data.head()
# Out:
#   airQualityLevel        observationDateTime deviceStatus aqiMajorPollutant  \
# 0    SATISFACTORY  2022-01-31 23:31:25+05:00       ACTIVE                CO
# 1    SATISFACTORY  2022-01-31 23:31:25+05:00       ACTIVE               NO2
# 2    SATISFACTORY  2022-01-31 23:31:25+05:00       ACTIVE               NO2
# 3    SATISFACTORY  2022-01-31 23:31:25+05:00       ACTIVE               NO2
# 4    SATISFACTORY  2022-01-31 23:31:25+05:00       ACTIVE                CO
#
#                                                   id  airQualityIndex  \
# 0  datakaveri.org/04a15c9960ffda227e9546f3f46e629...             71.0
# 1  datakaveri.org/04a15c9960ffda227e9546f3f46e629...             99.0
# 2  datakaveri.org/04a15c9960ffda227e9546f3f46e629...             81.0
# 3  datakaveri.org/04a15c9960ffda227e9546f3f46e629...             97.0
# 4  datakaveri.org/04a15c9960ffda227e9546f3f46e629...             72.0
#
#    uv.avgOverTime  o3.avgOverTime  pm2p5.avgOverTime  co2.avgOverTime  \
# 0             0.0           32.97              16.94           322.99
# 1             0.0            1.21              48.09           525.40
# 2             0.0           14.09              32.27           424.46
# 3             0.0           24.03              47.48           162.78
# 4             0.0           30.78              58.04             0.00
#
#    pm10.avgOverTime  co.avgOverTime  no2.avgOverTime  \
# 0             35.48            3.04            78.51
# 1             82.88            1.32           125.37
# 2             76.27            1.32            85.96
# 3             94.92            1.14            97.11
# 4             96.20            1.83            75.28
#
#    airTemperature.avgOverTime  illuminance.avgOverTime  \
# 0                       21.30                     4.52
# 1                       23.29                     3.23
# 2                       21.65                    24.61
# 3                       22.06                     1.39
# 4                       22.36                     2.89
#
#    ambientNoise.avgOverTime  so2.avgOverTime  relativeHumidity.avgOverTime  \
# 0                     74.53             0.06                         62.28
# 1                     76.57             2.42                         58.05
# 2                     71.48             0.24                         55.42
# 3                     84.27             4.80                         60.90
# 4                     81.63             4.30                         62.43
#
#    atmosphericPressure.avgOverTime
# 0                             0.46
# 1                             0.94
# 2                             0.93
# 3                             0.89
# 4                             0.94

# %%
# getting the columns
combined_data.columns
# Out:
# Index(['airQualityLevel', 'observationDateTime', 'deviceStatus',
#        'aqiMajorPollutant', 'id', 'airQualityIndex', 'uv.avgOverTime',
#        'o3.avgOverTime', 'pm2p5.avgOverTime', 'co2.avgOverTime',
#        'pm10.avgOverTime', 'co.avgOverTime', 'no2.avgOverTime',
#        'airTemperature.avgOverTime', 'illuminance.avgOverTime',
#        'ambientNoise.avgOverTime', 'so2.avgOverTime',
#        'relativeHumidity.avgOverTime', 'atmosphericPressure.avgOverTime'],
#       dtype='object')

# %% [markdown]
# ## Cleaning the Data

# %%
combined_data['observationDateTime'] =  pd.to_datetime(combined_data['observationDateTime'])
combined_data["observationDateTime"]
# Out:
# 0        2022-01-31 23:31:25+05:00
# 1        2022-01-31 23:31:25+05:00
# 2        2022-01-31 23:31:25+05:00
# 3        2022-01-31 23:31:25+05:00
# 4        2022-01-31 23:31:25+05:00
#                     ...
# 206656   2022-01-30 23:16:32+05:00
# 206657   2022-01-30 23:16:32+05:00
# 206658   2022-01-30 23:16:32+05:00
# 206659   2022-01-30 23:16:32+05:00
# 206660   2022-01-30 23:16:32+05:00
# Name: observationDateTime, Length: 206661, dtype: datetime64[ns, pytz.FixedOffset(300)]

# %%
combined_data.dropna(inplace=True)
combined_data.reset_index(inplace=True)

# %%
combined_data.isnull().sum()
# Out:
# index                              0
# airQualityLevel                    0
# observationDateTime                0
# deviceStatus                       0
# aqiMajorPollutant                  0
# id                                 0
# airQualityIndex                    0
# uv.avgOverTime                     0
# o3.avgOverTime                     0
# pm2p5.avgOverTime                  0
# co2.avgOverTime                    0
# pm10.avgOverTime                   0
# co.avgOverTime                     0
# no2.avgOverTime                    0
# airTemperature.avgOverTime         0
# illuminance.avgOverTime            0
# ambientNoise.avgOverTime           0
# so2.avgOverTime                    0
# relativeHumidity.avgOverTime       0
# atmosphericPressure.avgOverTime    0
# dtype: int64

# %% [markdown]
# ### Reading Location FIle

# %%
location_data=pd.read_csv("location.csv")
location_dict={}
for index, row in location_data.iterrows():
    location_dict[row['id']]={
        'coordinates':[row['latitude'], row['longitude']],
        'label':row['label']
    }
location_dict
# Out:
# {'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/f36b4669-628b-ad93-9970-f9d424afbf75': {'coordinates': [73.88559,
#    18.538425],
#   'label': 'Blue Diamond Square (Hotel Taj)_10'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/10b6d0f8-ae93-6622-5d1b-76af4bebc11e': {'coordinates': [73.836817,
#    18.572774],
#   'label': 'BopadiSquare_32'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/98bf83b7-a2b8-ea70-88aa-7d1d9f33dbe0': {'coordinates': [73.812648,
#    18.560589],
#   'label': 'Bremen Square_37'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/21ece4ba-0dcf-843a-16e0-35e0082277dd': {'coordinates': [73.783532,
#    18.507789],
#   'label': 'Chandani Square_25'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/17429134-c3d7-da41-0057-388a28723913': {'coordinates': [73.85259,
#    18.513701],
#   'label': 'Chitale Bandhu Corner_41'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/02f7e7ee-29d6-c1c1-4d98-8f74981d9683': {'coordinates': [73.903601,
#    18.539217],
#   'label': 'ABC_Farm_House_Junction_4'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/8cff12b2-b8be-1230-c5f6-ca96b4e4e441': {'coordinates': [73.873166,
#    18.552553],
#   'label': 'Ambedkar society circle_29'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/169af06f-bfee-3513-56e5-b9ddd7b863f0': {'coordinates': [73.853826,
#    18.51638],
#   'label': 'Appa_Balwant_Square_30'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/3c84ae0f-dcca-fd9b-1f09-bc0f0e092b63': {'coordinates': [73.881,
#    18.572668],
#   'label': 'BRTS Visharant wadi_38'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/2a072b6c-ec0b-d307-bdc6-86a8b585f5df': {'coordinates': [73.854234,
#    18.501188],
#   'label': 'Bajaj Statue Square_50'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/978ed964-88ee-fbc8-2092-5e41065c6405': {'coordinates': [73.828573,
#    18.541967],
#   'label': 'Pune_University_22'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/0ede317b-62b5-86e2-de37-604271f37d73': {'coordinates': [73.863397,
#    18.529833],
#   'label': 'RTO Square_8'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/763f8470-1fca-6f8b-3a8b-ee883a0c5f06': {'coordinates': [73.766392,
#    18.56857],
#   'label': 'Sadanand Hotel Square_39'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/a70a062d-1bc8-ba77-a530-af9b5d4f2145': {'coordinates': [73.876484,
#    18.525007],
#   'label': 'Sadhu_Wasvani_Square_24'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/388977ff-210f-b2f4-19e6-c619669708a2': {'coordinates': [73.869399,
#    18.501306],
#   'label': 'Seven Loves Square_16'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/2353b250-df9a-4108-8e2c-240955969d7e': {'coordinates': [73.84992,
#    18.530344],
#   'label': 'Shimla Office Square (Shivaji Nagar Chowk)_33'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/9426e6f0-71cc-d3f1-6466-760ac8b655a2': {'coordinates': [73.849475,
#    18.532001],
#   'label': 'Shivaji Nagar ST Stand_45'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/390a5098-1616-60ca-955e-ce9b5d3ee5f9': {'coordinates': [73.938842,
#    18.500945],
#   'label': 'Hadapsar_Gadital_01'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/d90466f6-a69a-6989-e54a-eddb4dc47fd4': {'coordinates': [73.848224,
#    18.522881],
#   'label': 'Jhanshi Rani Square_59'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/7bd8af4f-99bf-2f69-996c-5fde241fb29a': {'coordinates': [73.815409,
#    18.501802],
#   'label': 'Karve Statue Square_5'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/d3f2fcf3-24de-0fb6-7b74-0d7b3fa0467d': {'coordinates': [73.795248,
#    18.508049],
#   'label': 'Kothrud PMPML BusDepot_48'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/12bd3b5b-a189-0d10-3a1f-20a0ba699d7f': {'coordinates': [73.888922,
#    18.485643],
#   'label': 'Lullanagar_Square_14'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/c37c6979-6802-4a1c-c852-609b7706f5ba': {'coordinates': [73.857307,
#    18.489599],
#   'label': 'Market Yard Junction_02'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/f40c0b8e-248f-9f62-414e-7e2a7065d53e': {'coordinates': [73.932849,
#    18.532871],
#   'label': 'Mundhwa Road Junction_51'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/a841398a-4739-72ff-497a-a439364f459a': {'coordinates': [73.831273,
#    18.508766],
#   'label': 'Nalstop_Square_7'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/52e11fbe-2458-987f-b756-8c5cab1f051e': {'coordinates': [73.801601,
#    18.456863],
#   'label': 'Nanded City Entry_42'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/db3d6ea0-a84a-b3d6-7ec9-71ae66736273': {'coordinates': [73.927285,
#    18.502712],
#   'label': 'Noble Hospital junction_35'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/02b868e6-59f7-9359-3ae3-6feaf0e6bd9f': {'coordinates': [73.858556,
#    18.447118],
#   'label': 'PMPML Katraj_Depot_New_26'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/c7b8f786-2f89-116f-d98d-8c54bfc7caaf': {'coordinates': [73.842727,
#    18.516163],
#   'label': 'PMPML_Bus_Depot_Deccan_15'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/57c0323e-4cf7-2b22-0e54-e9c043d235cb': {'coordinates': [73.868533,
#    18.519513],
#   'label': 'Power_House_Square_43'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/b3ec32ff-fa7d-64fa-c0af-272e25d314e9': {'coordinates': [73.874251,
#    18.528387],
#   'label': 'Pune Railway Station_28'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/184ba502-22a8-ad15-a8f1-c966cd3aa7a7': {'coordinates': [73.872384,
#    18.527615],
#   'label': 'Pune_ST_Stand_40'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/83cdf03d-5787-7052-08aa-143cfbfb807d': {'coordinates': [73.850429,
#    18.531418],
#   'label': 'Shivaji_Nagar_Railway_Station_34'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/503328c5-a2ac-bfae-fd08-cf2630f51a7b': {'coordinates': [73.918006,
#    18.5652],
#   'label': 'Shree Krishna Hotel Square _12'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/a1198ebc-db62-1c31-28c6-09d51441f153': {'coordinates': [73.84607,
#    18.501086],
#   'label': 'Sinhgad Road Junction_9'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/3d3a569a-1a89-c3b6-671c-5675e4132c32': {'coordinates': [73.75385,
#    18.553421],
#   'label': 'Susgaon_46'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/2922b6ff-0271-cde4-9378-bd00f1a6ea3c': {'coordinates': [73.858437,
#    18.498368],
#   'label': 'Swargate ST Stand_13'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/b075ef08-a5cc-e920-6be3-f57e5b7731c5': {'coordinates': [73.830386,
#    18.520432],
#   'label': 'VS_Khandekar_Square_17'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/6e5c898e-23ee-f77a-82f5-ebc4998f5f4a': {'coordinates': [73.911371,
#    18.558336],
#   'label': 'Vadgaon_Sheri_Square_44'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/8011a665-ea2b-dd08-4c49-667bb2256545': {'coordinates': [73.913848,
#    18.565271],
#   'label': 'Datta Mandir Square_66'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/05fbae93-d3f7-0bbe-dd5d-2c2b4180edc7': {'coordinates': [73.884363,
#    18.541278],
#   'label': 'Dr Baba Saheb Ambedkar Sethu Junction_60'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/d824fa46-223b-f248-493e-80bb5bdeda68': {'coordinates': [73.952635,
#    18.48664],
#   'label': 'FursungiKaman_31'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/0541f9dd-2787-d791-9340-c30da7750de7': {'coordinates': [73.889322,
#    18.552602],
#   'label': 'Golf Club Junction_27'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/146a3c4f-c6e4-959f-e967-f0cfd5b03dcb': {'coordinates': [73.878603,
#    18.502865],
#   'label': 'Golibar Square_11'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/67ae0343-59e4-e88f-bc4a-f55e7789df44': {'coordinates': [73.841424,
#    18.517439],
#   'label': 'Goodluck Square_Cafe_23'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/b4b9e3b8-fcfa-08c2-a9c5-2093748a116c': {'coordinates': [73.889113,
#    18.546154],
#   'label': 'Gunjan Square_65'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/145bacfd-da11-d35f-ed80-ce7475d9bf3d': {'coordinates': [73.878518,
#    18.572404],
#   'label': 'Vishrantwadi junction_6'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/ae767590-445c-4079-14a6-6a954239d7c7': {'coordinates': [73.805765,
#    18.480309],
#   'label': 'Warje_Square_21'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/64131670-4db5-8b9b-6a81-7ddc23f176fd': {'coordinates': [73.840366,
#    18.509298],
#   'label': 'Ptrakar bhavn_72'},
#  'datakaveri.org/04a15c9960ffda227e9546f3f46e629e1fe4132b/rs.iudx.org.in/pune-env-aqm/3c4ebd7e-00e2-3881-ca79-281a1ba5bc22': {'coordinates': [73.835826,
#    18.500009],
#   'label': 'Sudhanshu society_36'}}

# %% [markdown]
# #### Mapping the sensors into the map

# %%
sensors_map=folium.Map()
for location_id, location_info in location_dict.items():
    folium.Marker([location_info["coordinates"][1], location_info["coordinates"][0]],
                  tooltip=location_info['label']).add_to(sensors_map)
sensors_map.fit_bounds(sensors_map.get_bounds())
sensors_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_39c19ece9b53185af7c4b6b9b92c5a65 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_39c19ece9b53185af7c4b6b9b92c5a65&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_39c19ece9b53185af7c4b6b9b92c5a65 = L.map(
#                 &quot;map_39c19ece9b53185af7c4b6b9b92c5a65&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_67fb2d24800e6ff8186cdff560a01fe2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_39c19ece9b53185af7c4b6b9b92c5a65);
#
#
#             var marker_d02b752191cc22543f4a2698f8d94e34 = L.marker(
#                 [18.538425, 73.88559],
#                 {}
#             ).addTo(map_39c19ece9b53185af7c4b6b9b92c5a65);
#
#
#             marker_d02b752191cc22543f4a2698f8d94e34.bindTooltip(
#                 `&lt;div&gt;
#                      Blue Diamond Square (Hotel Taj)_10
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b7e1a63c554e40601965324bff17fee6 = L.marker(
#                 [18.572774, 73.836817],
#                 {}
#             ).addTo(map_39c19ece9b53185af7c4b6b9b92c5a65);
#
#
#             marker_b7e1a63c554e40601965324bff17fee6.bindTooltip(
#                 `&lt;div&gt;
#                      BopadiSquare_32
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_355e91566ea49c7bb10b9164aeebd2a9 = L.marker(
#                 [18.560589, 73.812648],
#                 {}
#             ).addTo(map_39c19ece9b53185af7c4b6b9b92c5a65);
#
#
#             marker_355e91566ea49c7bb10b9164aeebd2a9.bindTooltip(
#                 `&lt;div&gt;
#                      Bremen Square_37
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6ab16a05a001362f344717fc2aa51c1e = L.marker(
#                 [18.507789, 73.783532],
#                 {}
#             ).addTo(map_39c19ece9b53185af7c4b6b9b92c5a65);
#
#
#             marker_6ab16a05a001362f344717fc2aa51c1e.bindTooltip(
#                 `&lt;div&gt;
#                      Chandani Square_25
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_29ae8e63884bc15a9633f22c437df6cd = L.marker(
#                 [18.513701, 73.85259],
#                 {}
#             ).addTo(map_39c19ece9b53185af7c4b6b9b92c5a65);
#
#
#             marker_29ae8e63884bc15a9633f22c437df6cd.bindTooltip(
#                 `&lt;div&gt;
#                      Chitale Bandhu Corner_41
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_16b92649f4e364f23799f2b00d16d9ee = L.marker(
#                 [18.539217, 73.903601],
#                 {}
#             ).addTo(map_39c19ece9b53185af7c4b6b9b92c5a65);
#
#
#             marker_16b92649f4e364f23799f2b00d16d9ee.bindTooltip(
#                 `&lt;div&gt;
#                      ABC_Farm_House_Junction_4
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_aeda6159c8ab72c5895317e62dc8090c = L.marker(
#                 [18.552553, 73.873166],
#                 {}
#             ).addTo(map_39c19ece9b53185af7c4b6b9b92c5a65);
#
#
#             marker_aeda6159c8ab72c5895317e62dc8090c.bindTooltip(
#                 `&lt;div&gt;
#                      Ambedkar society circle_29
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3ab34223c83074a7bd4b3f22e0f96eee = L.marker(
#                 [18.51638, 73.853826],
#                 {}
#             ).addTo(map_39c19ece9b53185af7c4b6b9b92c5a65);
#
#
#             marker_3ab34223c83074a7bd4b3f22e0f96eee.bindTooltip(
#                 `&lt;div&gt;
#                      Appa_Balwant_Square_30
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_be3ae540a4f71106b89f1c8f34dc4d75 = L.marker(
#                 [18.572668, 73.881],
#                 {}
#             ).addTo(map_39c19ece9b53185af7c4b6b9b92c5a65);
#
#
#             marker_be3ae540a4f71106b89f1c8f34dc4d75.bindTooltip(
#                 `&lt;div&gt;
#                      BRTS Visharant wadi_38
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9c0871e6d03a39ca1a9646a5bf7537c8 = L.marker(
#                 [18.501188, 73.854234],
#                 {}
#             ).addTo(map_39c19ece9b53185af7c4b6b9b92c5a65);
#
#
#             marker_9c0871e6d03a39ca1a9646a5bf7537c8.bindTooltip

# %%
# adding sensor location and label information to the dataframe
combined_data['latitude']=combined_data['id'].apply(lambda id:location_dict[id]['coordinates'][0])
combined_data['longitude']=combined_data['id'].apply(lambda id:location_dict[id]['coordinates'][1])
combined_data['label']=combined_data['id'].apply(lambda id:location_dict[id]['label'])
combined_data
# Out:
#          index airQualityLevel       observationDateTime deviceStatus  \
# 0            0    SATISFACTORY 2022-01-31 23:31:25+05:00       ACTIVE
# 1            1    SATISFACTORY 2022-01-31 23:31:25+05:00       ACTIVE
# 2            2    SATISFACTORY 2022-01-31 23:31:25+05:00       ACTIVE
# 3            3    SATISFACTORY 2022-01-31 23:31:25+05:00       ACTIVE
# 4            4    SATISFACTORY 2022-01-31 23:31:25+05:00       ACTIVE
# ...        ...             ...                       ...          ...
# 169444  206656        MODERATE 2022-01-30 23:16:32+05:00       ACTIVE
# 169445  206657        MODERATE 2022-01-30 23:16:32+05:00       ACTIVE
# 169446  206658    SATISFACTORY 2022-01-30 23:16:32+05:00       ACTIVE
# 169447  206659        MODERATE 2022-01-30 23:16:32+05:00       ACTIVE
# 169448  206660        MODERATE 2022-01-30 23:16:32+05:00       ACTIVE
#
#        aqiMajorPollutant                                                 id  \
# 0                     CO  datakaveri.org/04a15c9960ffda227e9546f3f46e629...
# 1                    NO2  datakaveri.org/04a15c9960ffda227e9546f3f46e629...
# 2                    NO2  datakaveri.org/04a15c9960ffda227e9546f3f46e629...
# 3                    NO2  datakaveri.org/04a15c9960ffda227e9546f3f46e629...
# 4                     CO  datakaveri.org/04a15c9960ffda227e9546f3f46e629...
# ...                  ...                                                ...
# 169444                CO  datakaveri.org/04a15c9960ffda227e9546f3f46e629...
# 169445                CO  datakaveri.org/04a15c9960ffda227e9546f3f46e629...
# 169446              PM10  datakaveri.org/04a15c9960ffda227e9546f3f46e629...
# 169447                CO  datakaveri.org/04a15c9960ffda227e9546f3f46e629...
# 169448                CO  datakaveri.org/04a15c9960ffda227e9546f3f46e629...
#
#         airQualityIndex  uv.avgOverTime  o3.avgOverTime  pm2p5.avgOverTime  \
# 0                  71.0             0.0           32.97              16.94
# 1                  99.0             0.0            1.21              48.09
# 2                  81.0             0.0           14.09              32.27
# 3                  97.0             0.0           24.03              47.48
# 4                  72.0             0.0           30.78              58.04
# ...                 ...             ...             ...                ...
# 169444            100.0             0.0            8.55              31.46
# 169445            109.0             0.0            0.00              41.08
# 169446             85.0             0.0            8.51              49.82
# 169447            105.0             0.0            0.00              74.10
# 169448            109.0             0.0            0.00              41.08
#
#         ...  no2.avgOverTime  airTemperature.avgOverTime  \
# 0       ...            78.51                       21.30
# 1       ...           125.37                       23.29
# 2       ...            85.96                       21.65
# 3       ...            97.11                       22.06
# 4       ...            75.28                       22.36
# ...     ...              ...                         ...
# 169444  ...            75.02                       22.56
# 169445  ...           105.07                       22.41
# 169446  ...            81.90                       20.89
# 169447  ...           108.52                       23.13
# 169448  ...           105.07                       22.41
#
#         illuminance.avgOverTime  ambientNoise.avgOverTime  so2.avgOverTime  \
# 0                          4.52                     74.53             0.06
# 1                          3.23                     76.57             2.42
# 2                         24.61                     71.48             0.24
# 3                          1.39                     84.27             4.80
# 4                          2.89                     81.63             4.30
# ...                         ...                       ...              ...
# 169444                     3.29                     72.09             3.25
# 169445                     2.62                     78.20             2.49
# 169446                    24.81                     72.40             0.00
# 169447                    19.65                     75.39             1.37
# 169448                     2.62                     78.20             2.49
#
#         relativeHumidity.avgOverTime  atmosphericPressure.avgOverTime  \
# 0                              62.28                             0.46
# 1                              58.05                             0.94
# 2                              55.42                             0.93
# 3                              60.90                             0.89
# 4                              62.43                             0.94
# ...                              ...                              ...
# 169444                         56.29                             0.94
# 169445                         56.14                             0.94
# 169446                         58.08                             0.93
# 169447                         52.31                             0.93
# 169448                         56.14                             0.94
#
#          latitude  longitude                               label
# 0       73.878603  18.502865                   Golibar Square_11
# 1       73.876484  18.525007             Sadhu_Wasvani_Square_24
# 2       73.753850  18.553421                          Susgaon_46
# 3       73.868533  18.519513               Power_House_Square_43
# 4       73.848224  18.522881              Jhanshi Rani Square_59
# ...           ...        ...                                 ...
# 169444  73.783532  18.507789                  Chandani Square_25
# 169445  73.885590  18.538425  Blue Diamond Square (Hotel Taj)_10
# 169446  73.753850  18.553421                          Susgaon_46
# 169447  73.952635  18.486640                    FursungiKaman_31
# 169448  73.885590  18.538425  Blue Diamond Square (Hotel Taj)_10
#
# [169449 rows x 23 columns]

# %%
sensor_ids = combined_data['id'].unique() ## Uniquely 50 sensors are present in the pune city
path="./sensorData"
if os.path.exists(path):
    shutil.rmtree(path)
os.makedirs(path)
for sensorid in sensor_ids:
    df=combined_data.loc[combined_data['id']==sensorid]
    mypath = "./sensorData/"+df['label'].unique()[0] +'.csv'
    df.to_csv(mypath,index=False)

# %% [markdown]
# ## Interpolating the values of pollution on the whole latitude
#
# Reference : https://towardsdatascience.com/visualizing-spatial-data-with-geojson-heatmaps-1fbe2063ab86

# %%
def interpolate_pollutant(pollutant,date,month,time):
    pollutant=pollutant+'.avgOverTime'
    df=combined_data[['observationDateTime','id', pollutant]]

# %%
# data on 15th January, 2022 at 5am

pollutant='co2'
pollutant=pollutant+'.avgOverTime'
df=combined_data[['observationDateTime','id', pollutant,'latitude','longitude','label']]
df=df[(df['observationDateTime'].dt.day==28) & (df['observationDateTime'].dt.month==1)]

# %%
final=df.groupby('label').mean()
final=final[~(final['co2.avgOverTime']== 0)]
latitude=final['latitude']
longitude=final['longitude']
zvalue=final['co2.avgOverTime']

# %%
#Interpolating values to get better coverage
xi = np.linspace(latitude.min(),latitude.max(),300);
yi = np.linspace(longitude.min(),longitude.max(),300);
zi = griddata((latitude, longitude), zvalue, (xi[None,:], yi[:,None]), method='linear')


#Creating contour plot with a step size of 1000
step_size=1000
# cs = mp.contourf(xi,yi,zi,range(5000,int( np.nanmax(zi))+step_size,step_size),cmap=mp.cm.jet)cs=
cs=mp.contourf(xi, yi, zi, levels=100,cmap=mp.cm.jet)

# %%
zi
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])

# %%
from scipy.interpolate import Rbf

grid_x, grid_y = np.mgrid[x_min:x_max:500, y_min:y_max:500]

# Make an n-dimensional interpolator. This is essential line number 4.
rbfi = Rbf(latitude, longitude, zvalue,function='gaussian')

# Predict on the regular grid. Line 5.
di = rbfi(xi, yi)
di
# mi = np.min(np.hstack([di.ravel(), zvalue.values]))
# ma = np.max(np.hstack([di.ravel(), zvalue.values]))

# c1 = mp.imshow(di.T, origin="lower", vmin=mi, vmax=ma)
# mp.colorbar(c1, shrink=0.67)
# mp.show()
# Out:
# array([   37.6122022 ,    48.57564634,    61.04926524,    74.45879545,
#           87.78788421,    99.48006097,   107.37040815,   108.67250003,
#          100.04879132,    77.79123424,    38.13196882,   -22.30956074,
#         -105.95686218,  -213.6234279 ,  -343.84423869,  -492.28608477,
#         -651.35052685,  -810.08959039,  -954.54189254, -1068.56223488,
#        -1135.16029476, -1138.2876299 , -1064.92515849,  -907.23832079,
#         -664.50006558,  -344.44924686,    36.2316347 ,   452.56136409,
#          873.13788241,  1263.18088803,  1588.46830777,  1819.70128816,
#         1936.68395392,  1931.6388472 ,  1811.02482758,  1595.39266648,
#         1317.09324888,  1016.00784956,   733.84102157,   507.8325402 ,
#          364.93411266,   317.50397434,   361.37416585,   476.7588348 ,
#          631.95825345,   789.26827947,   912.04163425,   971.57126404,
#          952.45016392,   855.32662283,   696.477246  ,   504.26397227,
#          313.18997918,   156.77975713,    60.76361047,    37.98403586,
#           86.06986081,   188.3239109 ,   317.57513602,   442.11296938,
#          532.39224516,   567.06520123,   537.08679165,   447.09972286,
#          313.92398467,   162.60678298,    20.98982497,   -85.98465426,
#         -141.02640671,  -137.38584286,   -79.41810144,    19.11174177,
#          138.44759254,   257.13817719,   356.26103421,   422.73646744,
#          451.16916158,   444.01764307,   410.25218323,   362.94315465,
#          316.37512965,   283.29306963,   272.77473895,   289.0305081 ,
#          331.21073174,   394.10144223,   469.44727101,   547.57364358,
#          618.98696486,   675.69568575,   712.0926506 ,   725.3444939 ,
#          715.3258327 ,   684.20088418,   635.78768234,   574.84240429,
#          506.38063342,   435.11819249,   365.07585871,   299.35734812])

# %%
import geojsoncontour

#Converting matplotplib contour plot to geojson
geojson = geojsoncontour.contourf_to_geojson(
        contourf=cs,
        min_angle_deg=3.0,
        ndigits=5,
        stroke_width=1,
        fill_opacity=0.5)

#reading geojson as dict
price_geojson=eval(geojson)

# %%
sensors_map=folium.Map(tiles="cartodbpositron")
for location_id, location_info in location_dict.items():
    folium.Marker([location_info["coordinates"][1], location_info["coordinates"][0]],
                  tooltip=location_info['label']).add_to(sensors_map)
folium.GeoJson(
        geojson,
        style_function=lambda x: {
            'color':     x['properties']['stroke'],
            'weight':    x['properties']['stroke-width'],
            'fillColor': x['properties']['fill'],
            'opacity':   0.1,
        }).add_to(sensors_map)

sensors_map.fit_bounds(sensors_map.get_bounds())
display(sensors_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0bd57b12819865b18e31a3b14784535c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0bd57b12819865b18e31a3b14784535c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0bd57b12819865b18e31a3b14784535c = L.map(
#                 &quot;map_0bd57b12819865b18e31a3b14784535c&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ee4915c67d79c54785378c03245c790 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0bd57b12819865b18e31a3b14784535c);
#
#
#             var marker_4566c0feff659a1615546ed964b96db6 = L.marker(
#                 [18.538425, 73.88559],
#                 {}
#             ).addTo(map_0bd57b12819865b18e31a3b14784535c);
#
#
#             marker_4566c0feff659a1615546ed964b96db6.bindTooltip(
#                 `&lt;div&gt;
#                      Blue Diamond Square (Hotel Taj)_10
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9df48da1b90c72ceb74f6811efa4c1c5 = L.marker(
#                 [18.572774, 73.836817],
#                 {}
#             ).addTo(map_0bd57b12819865b18e31a3b14784535c);
#
#
#             marker_9df48da1b90c72ceb74f6811efa4c1c5.bindTooltip(
#                 `&lt;div&gt;
#                      BopadiSquare_32
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_88e4bc8aff5e55b70c1aae874f2d141c = L.marker(
#                 [18.560589, 73.812648],
#                 {}
#             ).addTo(map_0bd57b12819865b18e31a3b14784535c);
#
#
#             marker_88e4bc8aff5e55b70c1aae874f2d141c.bindTooltip(
#                 `&lt;div&gt;
#                      Bremen Square_37
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6c4bfac56323ef3947f40f056b1208b0 = L.marker(
#                 [18.507789, 73.783532],
#                 {}
#             ).addTo(map_0bd57b12819865b18e31a3b14784535c);
#
#
#             marker_6c4bfac56323ef3947f40f056b1208b0.bindTooltip(
#                 `&lt;div&gt;
#                      Chandani Square_25
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_02badb34345c5148838fb1cea773b554 = L.marker(
#                 [18.513701, 73.85259],
#                 {}
#             ).addTo(map_0bd57b12819865b18e31a3b14784535c);
#
#
#             marker_02badb34345c5148838fb1cea773b554.bindTooltip(
#                 `&lt;div&gt;
#                      Chitale Bandhu Corner_41
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9997305a204e47c302e4468bd26f1277 = L.marker(
#                 [18.539217, 73.903601],
#                 {}
#             ).addTo(map_0bd57b12819865b18e31a3b14784535c);
#
#
#             marker_9997305a204e47c302e4468bd26f1277.bindTooltip(
#                 `&lt;div&gt;
#                      ABC_Farm_House_Junction_4
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b00933311bcdddc9809252b1f6911e0a = L.marker(
#                 [18.552553, 73.873166],
#                 {}
#             ).addTo(map_0bd57b12819865b18e31a3b14784535c);
#
#
#             marker_b00933311bcdddc9809252b1f6911e0a.bindTooltip(
#                 `&lt;div&gt;
#                      Ambedkar society circle_29
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_92b233b2100cb704fbdd23cbe9794744 = L.marker(
#                 [18.51638, 73.853826],
#                 {}
#             ).addTo(map_0bd57b12819865b18e31a3b14784535c);
#
#
#             marker_92b233b2100cb704fbdd23cbe9794744.bindTooltip(
#                 `&lt;div&gt;
#                      Appa_Balwant_Square_30
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1126025a71b1a94ce1f8525fa8c119f6 = L.marker(
#                 [18.572668, 73.881],
#                 {}
#             ).addTo(map_0bd57b12819865b18e31a3b14784535c);
#
#
#             marker_1126025a71b1a94ce1f8525fa8c119f6.bindTooltip(
#                 `&lt;div&gt;
#                      BRTS Visharant wadi_38
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_057aac3cf892f20406985d585f1ce1b2 = L.marker(
#                 [18.501188, 73.854234],

# %%
df[(df['observationDateTime'].dt.day==15) & (df['observationDateTime'].dt.month==1)]
# Out:
# Empty DataFrame
# Columns: [observationDateTime, id, co2.avgOverTime, latitude, longitude, label]
# Index: []

# %% [markdown]
# ### Answering the question

# %% [markdown]
# #### Specify major pollutant in the city

# %%
mp.figure(figsize = (16,5))
dataplot=sns.heatmap(pune_aqm.corr(), linewidths=1, linecolor='white',annot=True)
mp.show()

# %% [markdown]
# <p> Here we can find out a strong negative correlaation between relative humidity and average temperature. and we can also a strong positive  corelation between pm2p5 and airquality index and pm2p5 and pm10 as well as pm10 airquality </p>

# %%
pune_aqm.groupby('aqiMajorPollutant').count()['index']
# Out:
# aqiMajorPollutant
# CO       16020
# NO2      20485
# O3        1987
# PM10     16637
# PM2.5    44171
# Name: index, dtype: int64

# %% [markdown]
# <p> <b>Major pollutant in the city are :</b>
# </p>
#
# 1. PM 2.5
# 2. NO2
# 3. PM10
# 4. CO

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Conv1D, MaxPooling1D, Flatten, Flatten, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras import layers
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30788/23036163.py in <module>
# ----> 1 from tensorflow.keras import Sequential
#       2 from tensorflow.keras.layers import LSTM, Dense, Dropout, Conv1D, MaxPooling1D, Flatten, Flatten, Activation
#       3 from tensorflow.keras.models import Model
#       4 from tensorflow.keras.utils import plot_model
#       5 from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\tensorflow\__init__.py in <module>
#      35 import typing as _typing
#      36
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      39
#
# ModuleNotFoundError: No module named 'tensorflow.python'

# %%
# !pip3 install --upgrade pip3
# !pip3 uninstall tensorflow
# !pip3 install tensorflow
# Out:
# WARNING: Ignoring invalid distribution -ip (c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# ERROR: Could not find a version that satisfies the requirement pip3 (from versions: none)
# ERROR: No matching distribution found for pip3
# WARNING: Ignoring invalid distribution -ip (c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Skipping tensorflow as it is not installed.
# Collecting tensorflow
# WARNING: Ignoring invalid distribution -ip (c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
#   Using cached tensorflow-2.9.1-cp39-cp39-win_amd64.whl (444.0 MB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (1.13.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\site-packages (from tensorflow) (58.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (1.43.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (3.2.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (4.0.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (1.21.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (0.23.1)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (2.9.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: packaging in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (21.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.26.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.3.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from packaging->tensorflow) (2.4.7)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (4.10.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.0.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.1.1)
# Installing collected packages: tensorflow
# WARNING: Ignoring invalid distribution -ip (c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\Users\\Somesh\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python39\\site-packages\\tensorflow\\include\\external\\com_github_grpc_grpc\\src\\core\\ext\\filters\\client_channel\\lb_policy\\grpclb\\client_load_reporting_filter.h'
# HINT: This error might have occurred since this system does not have Windows Long Path support enabled. You can find information on how to enable this at https://pip.pypa.io/warnings/enable-long-paths
#
# WARNING: Ignoring invalid distribution -ip (c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\somesh\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
